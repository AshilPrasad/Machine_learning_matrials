# %%
import pandas as pd
from datetime import datetime
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import pickle

# %%
## Load the dataset
data=pd.read_excel(r"data\tdatanew.xlsx")
data
# Out:
#      transaction_id customer_id product_id   product_name   category  \
# 0           T000290       C0259       P004    Cricket Cap    Cricket
# 1           T000223       C0226       P019    Shuttlecock  Badminton
# 2           T000213       C0083       P019    Shuttlecock  Badminton
# 3           T000458       C0263       P014       Yoga Mat       Yoga
# 4           T000308       C0132       P027   Tennis Balls     Tennis
# ...             ...         ...        ...            ...        ...
# 2495        T000328       C0023       P015    Yoga Bottle       Yoga
# 2496        T000220       C0137       P001   Cricket Ball    Cricket
# 2497        T000227       C0100       P020  Badminton Net  Badminton
# 2498        T000259       C0234       P005       Football   Football
# 2499        T000173       C0348       P017     Yoga Towel       Yoga
#
#      purchase_date  quantity  price_per_unit  total_amount payment_method  \
# 0       2024-07-23         1             300           300     Debit Card
# 1       2025-03-11         1             150           150     Debit Card
# 2       2024-09-06         1             150           150     Debit Card
# 3       2025-05-18         1             700           700    Credit Card
# 4       2025-03-09         1             250           250     Debit Card
# ...            ...       ...             ...           ...            ...
# 2495    2024-01-04         1             350           350     Debit Card
# 2496    2024-08-30         1             200           200     Debit Card
# 2497    2024-09-16         3            1200          3600           Cash
# 2498    2024-11-06         1            1200          1200            UPI
# 2499    2024-02-12         1             250           250           Cash
#
#      store_location      Mobile
# 0           Kolkata  9400950651
# 1             Delhi  9400950651
# 2             Delhi  9400950651
# 3         Bangalore  9400950651
# 4           Kolkata  9400950651
# ...             ...         ...
# 2495         Mumbai  9400950651
# 2496          Delhi  9400950651
# 2497           Pune  9400950651
# 2498        Kolkata  9400950651
# 2499         Mumbai  9400950651
#
# [2500 rows x 12 columns]

# %%
group = data.groupby('customer_id').agg(
    Monetary=('total_amount', 'sum'),
    total_quantity=('quantity', 'sum'),
    Frequency=('transaction_id', 'count'),
    num_unique_products=('product_id', 'nunique'),
    last_purchase_date=('purchase_date', 'max'),
    avg_price_per_unit=('price_per_unit', 'mean'),
    store_visit_frequency=('purchase_date', 'nunique'),
).reset_index()
group
# Out:
#     customer_id  Monetary  total_quantity  Frequency  num_unique_products  \
# 0         C0000     26550              23         15                   12
# 1         C0001      5750               6          5                    5
# 2         C0003      9250               7          5                    5
# 3         C0004      8500               6          5                    5
# 4         C0006      8250               8          5                    5
# ..          ...       ...             ...        ...                  ...
# 282       C0395     12000               8          5                    5
# 283       C0396      7350               6          5                    5
# 284       C0397     11500              11         10                   10
# 285       C0398      7100               9          5                    5
# 286       C0399     14150              14         10                    8
#
#     last_purchase_date  avg_price_per_unit  store_visit_frequency
# 0           2025-01-07         1023.333333                      3
# 1           2024-05-06          790.000000                      1
# 2           2025-03-17         1130.000000                      1
# 3           2024-04-29         1460.000000                      1
# 4           2024-01-12         1150.000000                      1
# ..                 ...                 ...                    ...
# 282         2025-05-29         1340.000000                      1
# 283         2024-08-10         1230.000000                      1
# 284         2025-04-07         1030.000000                      2
# 285         2024-04-15          780.000000                      1
# 286         2025-03-27          870.000000                      2
#
# [287 rows x 8 columns]

# %%
membership_start = data.groupby('customer_id')['purchase_date'].min().reset_index()
membership_start.rename(columns={'purchase_date':'membership_start_date'}, inplace=True)

data = group.merge(membership_start, on='customer_id', how='left')
data
# Out:
#     customer_id  Monetary  total_quantity  Frequency  num_unique_products  \
# 0         C0000     26550              23         15                   12
# 1         C0001      5750               6          5                    5
# 2         C0003      9250               7          5                    5
# 3         C0004      8500               6          5                    5
# 4         C0006      8250               8          5                    5
# ..          ...       ...             ...        ...                  ...
# 282       C0395     12000               8          5                    5
# 283       C0396      7350               6          5                    5
# 284       C0397     11500              11         10                   10
# 285       C0398      7100               9          5                    5
# 286       C0399     14150              14         10                    8
#
#     last_purchase_date  avg_price_per_unit  store_visit_frequency  \
# 0           2025-01-07         1023.333333                      3
# 1           2024-05-06          790.000000                      1
# 2           2025-03-17         1130.000000                      1
# 3           2024-04-29         1460.000000                      1
# 4           2024-01-12         1150.000000                      1
# ..                 ...                 ...                    ...
# 282         2025-05-29         1340.000000                      1
# 283         2024-08-10         1230.000000                      1
# 284         2025-04-07         1030.000000                      2
# 285         2024-04-15          780.000000                      1
# 286         2025-03-27          870.000000                      2
#
#     membership_start_date
# 0              2024-05-26
# 1              2024-05-06
# 2              2025-03-17
# 3              2024-04-29
# 4              2024-01-12
# ..                    ...
# 282            2025-05-29
# 283            2024-08-10
# 284            2024-04-29
# 285            2024-04-15
# 286            2024-09-09
#
# [287 rows x 9 columns]

# %%
reference_date = pd.to_datetime(data['last_purchase_date'].max())
today = pd.to_datetime(datetime.today().date())



data['Active_days'] = ((reference_date - data['membership_start_date']).dt.days).round().astype(int)

data['Avg_purchase_gap_days'] = data.apply(
    lambda x: x['Active_days'] / x['store_visit_frequency'] if x['store_visit_frequency'] > 0 else x['Active_days'],
    axis=1
)


data['average_purchase_value'] = data['Monetary'] / data['total_quantity']
data['Recency'] = (today - data['last_purchase_date']).dt.days

data['last_purchase_date'] = data['last_purchase_date'].dt.date
data['membership_start_date'] = data['membership_start_date'].dt.date

data
# Out:
#     customer_id  Monetary  total_quantity  Frequency  num_unique_products  \
# 0         C0000     26550              23         15                   12
# 1         C0001      5750               6          5                    5
# 2         C0003      9250               7          5                    5
# 3         C0004      8500               6          5                    5
# 4         C0006      8250               8          5                    5
# ..          ...       ...             ...        ...                  ...
# 282       C0395     12000               8          5                    5
# 283       C0396      7350               6          5                    5
# 284       C0397     11500              11         10                   10
# 285       C0398      7100               9          5                    5
# 286       C0399     14150              14         10                    8
#
#     last_purchase_date  avg_price_per_unit  store_visit_frequency  \
# 0           2025-01-07         1023.333333                      3
# 1           2024-05-06          790.000000                      1
# 2           2025-03-17         1130.000000                      1
# 3           2024-04-29         1460.000000                      1
# 4           2024-01-12         1150.000000                      1
# ..                 ...                 ...                    ...
# 282         2025-05-29         1340.000000                      1
# 283         2024-08-10         1230.000000                      1
# 284         2025-04-07         1030.000000                      2
# 285         2024-04-15          780.000000                      1
# 286         2025-03-27          870.000000                      2
#
#     membership_start_date  Active_days  Avg_purchase_gap_days  \
# 0              2024-05-26          370             123.333333
# 1              2024-05-06          390             390.000000
# 2              2025-03-17           75              75.000000
# 3              2024-04-29          397             397.000000
# 4              2024-01-12          505             505.000000
# ..                    ...          ...                    ...
# 282            2025-05-29            2               2.000000
# 283            2024-08-10          294             294.000000
# 284            2024-04-29          397             198.500000
# 285            2024-04-15          411             411.000000
# 286            2024-09-09          264             132.000000
#
#      average_purchase_value  Recency
# 0               1154.347826      154
# 1                958.333333      400
# 2               1321.428571       85
# 3               1416.666667      407
# 4               1031.250000      515
# ..                      ...      ...
# 282             1500.000000       12
# 283             1225.000000      304
# 284             1045.454545       64
# 285              788.888889      421
# 286             1010.714286       75
#
# [287 rows x 13 columns]

# %%
# Create a more comprehensive churn label
data['churn'] = data.apply(lambda row: 1 if (
    (row['Recency'] > 1 * row['Avg_purchase_gap_days']) and  # More lenient recency threshold
    (row['Monetary'] < data['Monetary'].median()) and       # Low monetary value
    (row['Frequency'] < data['Frequency'].median())         # Low frequency
) else 0, axis=1)

data

print("Churn Distribution:")
print(data['churn'].value_counts(normalize=True))
# Out:
# Churn Distribution:
# churn
# 0    1.0
# Name: proportion, dtype: float64

# %%
x=data[['Monetary','Frequency','Avg_purchase_gap_days','Recency']]           
y=data['churn']
x
# Out:
#      Monetary  Frequency  Avg_purchase_gap_days  Recency
# 0       26550         15             123.333333      154
# 1        5750          5             390.000000      400
# 2        9250          5              75.000000       85
# 3        8500          5             397.000000      407
# 4        8250          5             505.000000      515
# ..        ...        ...                    ...      ...
# 282     12000          5               2.000000       12
# 283      7350          5             294.000000      304
# 284     11500         10             198.500000       64
# 285      7100          5             411.000000      421
# 286     14150         10             132.000000       75
#
# [287 rows x 4 columns]

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)
x_train
# Out:
#      Monetary  Frequency  Avg_purchase_gap_days  Recency
# 140     13650         15             131.000000      158
# 25       3800          5             232.000000      242
# 132      4550          5             387.000000      397
# 219      4700          5              44.000000       54
# 66       6850          5             199.000000      209
# ..        ...        ...                    ...      ...
# 188      4750          5             507.000000      517
# 71      17150         15             158.333333      317
# 106     13000         10             155.500000      265
# 270      5950          5             215.000000      225
# 102      5100          5             409.000000      419
#
# [229 rows x 4 columns]

# %%
scaler=StandardScaler()
x_train=scaler.fit_transform(x_train)
x_test=scaler.fit_transform(x_test)
x_train
# Out:
# array([[ 4.45990091e-01,  1.29250434e+00, -6.16133749e-01,
#         -4.60325649e-01],
#        [-1.02681212e+00, -7.70098406e-01,  1.98789193e-01,
#          1.30784110e-01],
#        [-9.14669817e-01, -7.70098406e-01,  1.44941351e+00,
#          1.22152236e+00],
#        [-8.92241357e-01, -7.70098406e-01, -1.31809708e+00,
#         -1.19217583e+00],
#        [-5.70766764e-01, -7.70098406e-01, -6.74727586e-02,
#         -1.01437581e-01],
#        [ 4.08609324e-01, -7.70098406e-01, -1.34230271e+00,
#         -1.21328689e+00],
#        [-4.66100617e-01, -7.70098406e-01,  2.29661063e+00,
#          1.96040955e+00],
#        [ 7.96585771e-02,  2.61202968e-01, -9.57126626e-02,
#          1.44858152e-01],
#        [-5.78242917e-01, -7.70098406e-01,  2.71406089e-01,
#          1.94117298e-01],
#        [-3.68910623e-01,  2.61202968e-01, -1.22127455e+00,
#        [ 2.44212303e+00,  1.29250434e+00, -4.41315296e-01,
#         -1.27662008e+00],
#        [-7.65146751e-01, -7.70098406e-01,  1.32838535e+00,
#          1.11596704e+00],
#        [-6.98644897e-02,  2.61202968e-01, -3.92328547e-02,
#         -8.54398822e-01],
#        [-6.82909064e-01, -7.70098406e-01,  1.94159469e+00,
#          1.65078063e+00],
#        [ 6.47846231e-01, -7.70098406e-01, -1.19706892e+00,
#         -1.08662051e+00],
#        [ 1.15622466e+00,  1.29250434e+00, -3.87525003e-01,
#         -1.31884220e+00],
#        [ 2.81514717e-01,  2.61202968e-01,  1.06000937e-01,
#          7.35967910e-01],
#        [-5.10957537e-01, -7.70098406e-01,  2.06857737e-01,
#          1.37821131e-01],
#        [-1.16138288e+00, -7.70098406e-01, -1.39071397e+00,
#         -1.25550902e+00],
#        [ 6.32893924e-01,  1.29250434e+00, -1.07335124e+00,
#         -1.38921241e+00],
#        [-6.23099837e-01, -7.70098406e-01, -1.14865765e+00,
#         -1.04439839e+00],
#        [ 1.22351004e+00,  1.29250434e+00,  8.17953050e-02,
#          7.00782806e-01],
#        [ 1.98493504e-02,  2.61202968e-01,  2.99645993e-01,
#          5.53005366e-01],
#        [ 4.75894704e-01,  2.61202968e-01,  1.10035209e-01,
#          1.16710068e-01],
#        [ 4.68418551e-01,  2.61202968e-01, -7.37161909e-01,
#         -1.21328689e+00],
#        [ 4.16085477e-01,  2.61202968e-01,  3.19817353e-01,
#          7.00782806e-01],
#        [ 5.20751624e-01,  2.61202968e-01, -6.08065205e-01,
#         -1.04439839e+00],
#        [-5.93195224e-01,  2.61202968e-01, -3.90214518e-01,
#          5.10783240e-01],
#        [-8.84765204e-01, -7.70098406e-01,  2.41763879e+00,
#          2.06596487e+00],
#        [ 9.69320825e-01,  1.29250434e+00, -3.95593547e-01,
#          6.58560680e-01],
#        [ 3.48800097e-01,  2.61202968e-01, -4.18454422e-01,
#          2.92635591e-01],
#        [-7.05337524e-01, -7.70098406e-01,  6.16239451e-02,
#          1.11547537e-02],
#        [-8.32432131e-01, -7.70098406e-01,  1.62692148e+00,
#          1.37633682e+00]])

# %%
with open('Models/churn_scaler.pkl','wb') as file:
    pickle.dump(scaler,file)

# %%
data
# Out:
#     customer_id  Monetary  total_quantity  Frequency  num_unique_products  \
# 0         C0000     26550              23         15                   12
# 1         C0001      5750               6          5                    5
# 2         C0003      9250               7          5                    5
# 3         C0004      8500               6          5                    5
# 4         C0006      8250               8          5                    5
# ..          ...       ...             ...        ...                  ...
# 282       C0395     12000               8          5                    5
# 283       C0396      7350               6          5                    5
# 284       C0397     11500              11         10                   10
# 285       C0398      7100               9          5                    5
# 286       C0399     14150              14         10                    8
#
#     last_purchase_date  avg_price_per_unit  store_visit_frequency  \
# 0           2025-01-07         1023.333333                      3
# 1           2024-05-06          790.000000                      1
# 2           2025-03-17         1130.000000                      1
# 3           2024-04-29         1460.000000                      1
# 4           2024-01-12         1150.000000                      1
# ..                 ...                 ...                    ...
# 282         2025-05-29         1340.000000                      1
# 283         2024-08-10         1230.000000                      1
# 284         2025-04-07         1030.000000                      2
# 285         2024-04-15          780.000000                      1
# 286         2025-03-27          870.000000                      2
#
#     membership_start_date  Active_days  Avg_purchase_gap_days  \
# 0              2024-05-26          370             123.333333
# 1              2024-05-06          390             390.000000
# 2              2025-03-17           75              75.000000
# 3              2024-04-29          397             397.000000
# 4              2024-01-12          505             505.000000
# ..                    ...          ...                    ...
# 282            2025-05-29            2               2.000000
# 283            2024-08-10          294             294.000000
# 284            2024-04-29          397             198.500000
# 285            2024-04-15          411             411.000000
# 286            2024-09-09          264             132.000000
#
#      average_purchase_value  Recency  churn
# 0               1154.347826      154      0
# 1                958.333333      400      0
# 2               1321.428571       85      0
# 3               1416.666667      407      0
# 4               1031.250000      515      0
# ..                      ...      ...    ...
# 282             1500.000000       12      0
# 283             1225.000000      304      0
# 284             1045.454545       64      0
# 285              788.888889      421      0
# 286             1010.714286       75      0
#
# [287 rows x 14 columns]

# %% [markdown]
# ### ANN Implementation

# %%
import tensorflow
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Input, Dense
from tensorflow.keras.callbacks import EarlyStopping,TensorBoard
import datetime

# %%
(x_train.shape[1],)
# Out:
# (4,)

# %%
churn_model = Sequential([
    Input(shape=(x_train.shape[1],)),  # Input layer
    Dense(64, activation='relu'),      # Hidden Layer 1
    Dense(32, activation='relu'),      # Hidden Layer 2
    Dense(1, activation='sigmoid')     # Output Layer
])

# %%
churn_model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 64)             │           320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 1)              │            33 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 2,433 (9.50 KB)
#  Trainable params: 2,433 (9.50 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
opt=tf.keras.optimizers.Adam(learning_rate=0.01)
loss=tf.keras.losses.BinaryCrossentropy()
loss
# Out:
# <LossFunctionWrapper(<function binary_crossentropy at 0x0000028DEF8500D0>, kwargs={'from_logits': False, 'label_smoothing': 0.0, 'axis': -1})>

# %%
churn_model.compile(optimizer=opt,loss="binary_crossentropy",metrics=['accuracy'])

# %%
log_dir="logs/fit/" + datetime.datetime.now().strftime("%Y%m%d-%H%M%S")
tensorflow_callback=TensorBoard(log_dir=log_dir,histogram_freq=1)

# %%
## Set up Early Stopping
early_stopping_callback=EarlyStopping(monitor='val_loss',patience=15,restore_best_weights=True)

# %%
### Train the model
history=churn_model.fit(
    x_train,y_train,validation_data=(x_test,y_test),epochs=100,
    callbacks=[tensorflow_callback,early_stopping_callback]
)
# Out:
# Epoch 1/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 75ms/step - accuracy: 0.7606 - loss: 0.4903 - val_accuracy: 1.0000 - val_loss: 0.0604
# Epoch 2/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 1.0000 - loss: 0.0365 - val_accuracy: 1.0000 - val_loss: 0.0029
# Epoch 3/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 1.0000 - loss: 0.0014 - val_accuracy: 1.0000 - val_loss: 3.9257e-04
# Epoch 4/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 1.0000 - loss: 2.0614e-04 - val_accuracy: 1.0000 - val_loss: 1.2474e-04
# Epoch 5/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 1.0000 - loss: 6.7476e-05 - val_accuracy: 1.0000 - val_loss: 6.7400e-05
# Epoch 6/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 1.0000 - loss: 3.6905e-05 - val_accuracy: 1.0000 - val_loss: 4.8885e-05
# Epoch 7/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 1.0000 - loss: 2.4559e-05 - val_accuracy: 1.0000 - val_loss: 4.1611e-05
# Epoch 8/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 1.0000 - loss: 2.0552e-05 - val_accuracy: 1.0000 - val_loss: 3.8244e-05
# Epoch 9/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 1.0000 - loss: 2.5203e-05 - val_accuracy: 1.0000 - val_loss: 3.6460e-05
# Epoch 10/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 1.0000 - loss: 1.8681e-05 - val_accuracy: 1.0000 - val_loss: 3.5384e-05
# Epoch 11/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 1.0000 - loss: 1.6789e-05 - val_accuracy: 1.0000 - val_loss: 3.4621e-05
# Epoch 12/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 1.0000 - loss: 2.1288e-05 - val_accuracy: 1.0000 - val_loss: 3.3958e-05
# Epoch 13/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 1.0000 - loss: 2.2881e-05 - val_accuracy: 1.0000 - val_loss: 3.3336e-05
# Epoch 14/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 1.0000 - loss: 1.3263e-05 - val_accuracy: 1.0000 - val_loss: 3.2659e-05
# Epoch 15/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 1.0000 - loss: 1.7661e-05 - val_accuracy: 1.0000 - val_loss: 3.1986e-05
# Epoch 16/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 1.0000 - loss: 1.7137e-05 - val_accuracy: 1.0000 - val_loss: 3.1379e-05
# Epoch 17/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 1.0000 - loss: 1.4405e-05 - val_accuracy: 1.0000 - val_loss: 3.0837e-05
# Epoch 18/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 1.0000 - loss: 2.1055e-05 - val_accuracy: 1.0000 - val_loss: 3.0277e-05
# Epoch 19/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 1.0000 - loss: 1.2427e-05 - val_accuracy: 1.0000 - val_loss: 2.9756e-05
# Epoch 20/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 1.0000 - loss: 1.4255e-05 - val_accuracy: 1.0000 - val_loss: 2.9146e-05
# Epoch 21/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 1.0000 - loss: 1.9561e-05 - val_accuracy: 1.0000 - val_loss: 2.8552e-05
# Epoch 22/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 1.0000 - loss: 2.2528e-05 - val_accuracy: 1.0000 - val_loss: 2.7868e-05
# Epoch 23/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 1.0000 - loss: 2.2312e-05 - val_accuracy: 1.0000 - val_loss: 2.7205e-05
# Epoch 24/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 1.0000 - loss: 1.5023e-05 - val_accuracy: 1.0000 - val_loss: 2.6625e-05
# Epoch 25/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 1.0000 - loss: 1.7955e-05 - val_accuracy: 1.0000 - val_loss: 2.6094e-05
# Epoch 26/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 1.0000 - loss: 1.6113e-05 - val_accuracy: 1.0000 - val_loss: 2.5589e-05
# Epoch 27/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 1.0000 - loss: 1.7861e-05 - val_accuracy: 1.0000 - val_loss: 2.5092e-05
# Epoch 28/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 1.0000 - loss: 1.7314e-05 - val_accuracy: 1.0000 - val_loss: 2.4604e-05
# Epoch 29/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 1.0000 - loss: 1.3431e-05 - val_accuracy: 1.0000 - val_loss: 2.4166e-05
# Epoch 30/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 1.0000 - loss: 1.6635e-05 - val_accuracy: 1.0000 - val_loss: 2.3697e-05
# Epoch 31/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 1.0000 - loss: 1.3624e-05 - val_accuracy: 1.0000 - val_loss: 2.3262e-05
# Epoch 32/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 1.0000 - loss: 1.6293e-05 - val_accuracy: 1.0000 - val_loss: 2.2798e-05
# Epoch 33/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 1.0000 - loss: 1.1148e-05 - val_accuracy: 1.0000 - val_loss: 2.2384e-05
# Epoch 34/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 1.0000 - loss: 1.3204e-05 - val_accuracy: 1.0000 - val_loss: 2.1943e-05
# Epoch 35/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 1.0000 - loss: 1.2007e-05 - val_accuracy: 1.0000 - val_loss: 2.1511e-05
# Epoch 36/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 1.0000 - loss: 1.0598e-05 - val_accuracy: 1.0000 - val_loss: 2.1059e-05
# Epoch 37/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 1.0000 - loss: 1.0551e-05 - val_accuracy: 1.0000 - val_loss: 2.0620e-05
# Epoch 38/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 1.0000 - loss: 1.0487e-05 - val_accuracy: 1.0000 - val_loss: 2.0202e-05
# Epoch 39/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 1.0000 - loss: 1.4078e-05 - val_accuracy: 1.0000 - val_loss: 1.9780e-05
# Epoch 40/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 1.0000 - loss: 1.1651e-05 - val_accuracy: 1.0000 - val_loss: 1.9378e-05
# Epoch 41/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 1.0000 - loss: 1.0464e-05 - val_accuracy: 1.0000 - val_loss: 1.8999e-05
# Epoch 42/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 1.0000 - loss: 1.2478e-05 - val_accuracy: 1.0000 - val_loss: 1.8577e-05
# Epoch 43/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 1.0000 - loss: 1.1257e-05 - val_accuracy: 1.0000 - val_loss: 1.8146e-05
# Epoch 44/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 1.0000 - loss: 7.7596e-06 - val_accuracy: 1.0000 - val_loss: 1.7731e-05
# Epoch 45/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 1.0000 - loss: 9.8902e-06 - val_accuracy: 1.0000 - val_loss: 1.7353e-05
# Epoch 46/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 1.0000 - loss: 8.3298e-06 - val_accuracy: 1.0000 - val_loss: 1.6999e-05
# Epoch 47/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 1.0000 - loss: 9.9923e-06 - val_accuracy: 1.0000 - val_loss: 1.6598e-05
# Epoch 48/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 1.0000 - loss: 8.4225e-06 - val_accuracy: 1.0000 - val_loss: 1.6209e-05
# Epoch 49/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 1.0000 - loss: 9.2975e-06 - val_accuracy: 1.0000 - val_loss: 1.5818e-05
# Epoch 50/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 1.0000 - loss: 8.9455e-06 - val_accuracy: 1.0000 - val_loss: 1.5482e-05
# Epoch 51/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 1.0000 - loss: 1.0465e-05 - val_accuracy: 1.0000 - val_loss: 1.5160e-05
# Epoch 52/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 1.0000 - loss: 8.1350e-06 - val_accuracy: 1.0000 - val_loss: 1.4868e-05
# Epoch 53/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 1.0000 - loss: 7.0677e-06 - val_accuracy: 1.0000 - val_loss: 1.4606e-05
# Epoch 54/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 1.0000 - loss: 9.4383e-06 - val_accuracy: 1.0000 - val_loss: 1.4321e-05
# Epoch 55/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 1.0000 - loss: 7.0961e-06 - val_accuracy: 1.0000 - val_loss: 1.4027e-05
# Epoch 56/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 1.0000 - loss: 8.2283e-06 - val_accuracy: 1.0000 - val_loss: 1.3696e-05
# Epoch 57/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 1.0000 - loss: 7.2467e-06 - val_accuracy: 1.0000 - val_loss: 1.3411e-05
# Epoch 58/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 1.0000 - loss: 7.4186e-06 - val_accuracy: 1.0000 - val_loss: 1.3153e-05
# Epoch 59/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 1.0000 - loss: 5.5148e-06 - val_accuracy: 1.0000 - val_loss: 1.2920e-05
# Epoch 60/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 1.0000 - loss: 8.0520e-06 - val_accuracy: 1.0000 - val_loss: 1.2661e-05
# Epoch 61/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 1.0000 - loss: 7.5268e-06 - val_accuracy: 1.0000 - val_loss: 1.2415e-05
# Epoch 62/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 1.0000 - loss: 6.3013e-06 - val_accuracy: 1.0000 - val_loss: 1.2179e-05
# Epoch 63/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 1.0000 - loss: 6.0960e-06 - val_accuracy: 1.0000 - val_loss: 1.1929e-05
# Epoch 64/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 1.0000 - loss: 6.2105e-06 - val_accuracy: 1.0000 - val_loss: 1.1711e-05
# Epoch 65/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 1.0000 - loss: 6.8723e-06 - val_accuracy: 1.0000 - val_loss: 1.1496e-05
# Epoch 66/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 1.0000 - loss: 6.9958e-06 - val_accuracy: 1.0000 - val_loss: 1.1286e-05
# Epoch 67/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 1.0000 - loss: 6.4421e-06 - val_accuracy: 1.0000 - val_loss: 1.1087e-05
# Epoch 68/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 1.0000 - loss: 5.6642e-06 - val_accuracy: 1.0000 - val_loss: 1.0905e-05
# Epoch 69/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 1.0000 - loss: 7.0768e-06 - val_accuracy: 1.0000 - val_loss: 1.0712e-05
# Epoch 70/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 1.0000 - loss: 6.3962e-06 - val_accuracy: 1.0000 - val_loss: 1.0528e-05
# Epoch 71/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 1.0000 - loss: 5.8753e-06 - val_accuracy: 1.0000 - val_loss: 1.0344e-05
# Epoch 72/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 1.0000 - loss: 5.7929e-06 - val_accuracy: 1.0000 - val_loss: 1.0155e-05
# Epoch 73/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 1.0000 - loss: 7.6758e-06 - val_accuracy: 1.0000 - val_loss: 9.9753e-06
# Epoch 74/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 1.0000 - loss: 5.9224e-06 - val_accuracy: 1.0000 - val_loss: 9.8118e-06
# Epoch 75/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 1.0000 - loss: 7.0420e-06 - val_accuracy: 1.0000 - val_loss: 9.6494e-06
# Epoch 76/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 1.0000 - loss: 6.7667e-06 - val_accuracy: 1.0000 - val_loss: 9.4907e-06
# Epoch 77/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 1.0000 - loss: 6.2389e-06 - val_accuracy: 1.0000 - val_loss: 9.3418e-06
# Epoch 78/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 1.0000 - loss: 4.3820e-06 - val_accuracy: 1.0000 - val_loss: 9.1884e-06
# Epoch 79/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 1.0000 - loss: 6.9898e-06 - val_accuracy: 1.0000 - val_loss: 9.0265e-06
# Epoch 80/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 1.0000 - loss: 4.6596e-06 - val_accuracy: 1.0000 - val_loss: 8.8538e-06
# Epoch 81/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 1.0000 - loss: 5.8511e-06 - val_accuracy: 1.0000 - val_loss: 8.6971e-06
# Epoch 82/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 1.0000 - loss: 4.0913e-06 - val_accuracy: 1.0000 - val_loss: 8.5526e-06
# Epoch 83/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 1.0000 - loss: 4.4577e-06 - val_accuracy: 1.0000 - val_loss: 8.3933e-06
# Epoch 84/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 1.0000 - loss: 4.8878e-06 - val_accuracy: 1.0000 - val_loss: 8.2483e-06
# Epoch 85/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 1.0000 - loss: 3.9599e-06 - val_accuracy: 1.0000 - val_loss: 8.1166e-06
# Epoch 86/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 1.0000 - loss: 3.4002e-06 - val_accuracy: 1.0000 - val_loss: 7.9688e-06
# Epoch 87/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 1.0000 - loss: 4.2897e-06 - val_accuracy: 1.0000 - val_loss: 7.8281e-06
# Epoch 88/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 1.0000 - loss: 3.9831e-06 - val_accuracy: 1.0000 - val_loss: 7.6803e-06
# Epoch 89/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 1.0000 - loss: 4.0528e-06 - val_accuracy: 1.0000 - val_loss: 7.5495e-06
# Epoch 90/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 1.0000 - loss: 4.6613e-06 - val_accuracy: 1.0000 - val_loss: 7.4276e-06
# Epoch 91/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 1.0000 - loss: 4.0480e-06 - val_accuracy: 1.0000 - val_loss: 7.3130e-06
# Epoch 92/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 1.0000 - loss: 4.7191e-06 - val_accuracy: 1.0000 - val_loss: 7.1988e-06
# Epoch 93/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 1.0000 - loss: 3.4817e-06 - val_accuracy: 1.0000 - val_loss: 7.0970e-06
# Epoch 94/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 1.0000 - loss: 3.8869e-06 - val_accuracy: 1.0000 - val_loss: 6.9904e-06
# Epoch 95/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 1.0000 - loss: 4.8428e-06 - val_accuracy: 1.0000 - val_loss: 6.8840e-06
# Epoch 96/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 1.0000 - loss: 4.3086e-06 - val_accuracy: 1.0000 - val_loss: 6.7740e-06
# Epoch 97/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 1.0000 - loss: 4.7892e-06 - val_accuracy: 1.0000 - val_loss: 6.6660e-06
# Epoch 98/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 1.0000 - loss: 4.9449e-06 - val_accuracy: 1.0000 - val_loss: 6.5635e-06
# Epoch 99/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 1.0000 - loss: 4.1569e-06 - val_accuracy: 1.0000 - val_loss: 6.4735e-06
# Epoch 100/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 1.0000 - loss: 3.7925e-06 - val_accuracy: 1.0000 - val_loss: 6.3823e-06

# %%
train_accuracy = history.history['accuracy']
val_accuracy = history.history['val_accuracy']
print(f"train_accuracy :",train_accuracy[-1])
print("val_accuracy :",val_accuracy[-1])
# Out:
# train_accuracy : 1.0
# val_accuracy : 1.0

# %%
churn_model.save('Models/churn_model.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
## Load Tensorboard Extension
# %load_ext tensorboard

# %%
# %tensorboard --logdir logs/fit
# Out:
# Reusing TensorBoard on port 6006 (pid 8744), started 3 days, 13:47:37 ago. (Use '!kill 8744' to kill it.)
#       <iframe id="tensorboard-frame-8a771cb23073a887" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-8a771cb23073a887");
#           const url = new URL("http://localhost");
#           const port = 6006;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>

# %%
### Load the pickle file
